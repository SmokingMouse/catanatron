# %%
import sys
sys.path.append('/home/smokingmouse/python/catanatron/catanatron_core')

# %%
from catanatron.game import Game
import catanatron.models.player as players

# %%
game = Game(players=[players.SimplePlayer(players.Color.BLUE), players.RandomPlayer(players.Color.RED)])

# %%
game.play()
# Out:
# 0: ActionType.BUILD_SETTLEMENT 2
# 1: ActionType.BUILD_SETTLEMENT 3
# 2: ActionType.BUILD_SETTLEMENT 4
# 3: ActionType.BUILD_SETTLEMENT 9
# 4: ActionType.BUILD_SETTLEMENT 10
# 5: ActionType.BUILD_SETTLEMENT 11
# 6: ActionType.BUILD_SETTLEMENT 12
# 7: ActionType.BUILD_SETTLEMENT 13
# 8: ActionType.BUILD_SETTLEMENT 14
# 9: ActionType.BUILD_SETTLEMENT 15
# 10: ActionType.BUILD_SETTLEMENT 16
# 11: ActionType.BUILD_SETTLEMENT 17
# 12: ActionType.BUILD_SETTLEMENT 18
# 13: ActionType.BUILD_SETTLEMENT 19
# 14: ActionType.BUILD_SETTLEMENT 21
# 15: ActionType.BUILD_SETTLEMENT 22
# 16: ActionType.BUILD_SETTLEMENT 23
# 17: ActionType.BUILD_SETTLEMENT 25
# 18: ActionType.BUILD_SETTLEMENT 26
# 19: ActionType.BUILD_SETTLEMENT 27
# 20: ActionType.BUILD_SETTLEMENT 28
# 21: ActionType.BUILD_SETTLEMENT 29
# 22: ActionType.BUILD_SETTLEMENT 30
# 23: ActionType.BUILD_SETTLEMENT 31
# 24: ActionType.BUILD_SETTLEMENT 32
# 25: ActionType.BUILD_SETTLEMENT 33
# 26: ActionType.BUILD_SETTLEMENT 34
# ...
